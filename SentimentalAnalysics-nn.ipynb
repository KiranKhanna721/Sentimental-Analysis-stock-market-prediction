# %% [markdown]
# # Web Scrapping the dataset

# %%
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
from urllib.request import urlopen
from urllib.request import Request
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import numpy as np
from textblob import TextBlob
from nltk.corpus import stopwords
from collections import Counter
import warnings; warnings.simplefilter('ignore')
import nltk
import string
from nltk import ngrams
from nltk.tokenize import word_tokenize 
from nltk.stem import SnowballStemmer

# %%
n = 1000

# %%
tickers = ['TCS']

# %%
finviz_url = 'https://finviz.com/quote.ashx?t='
news_tables = {}

for ticker in tickers:
    url = finviz_url + ticker
    req = Request(url=url,headers={'user-agent': 'my-app/0.0.1'}) 
    resp = urlopen(req)    
    html = BeautifulSoup(resp, features="lxml")
    news_table = html.find(id='news-table')
    news_tables[ticker] = news_table

try:
    for ticker in tickers:
        df = news_tables[ticker]
        df_tr = df.findAll('tr')
    
        print ('\n')
        print ('Recent News Headlines for {}: '.format(ticker))
        
        for i, table_row in enumerate(df_tr):
            a_text = table_row.a.text
            td_text = table_row.td.text
            td_text = td_text.strip()
            print(a_text,'(',td_text,')')
            if i == n-1:
                break
except KeyError:
    pass
# Out:
# Recent News Headlines for TCS:
# The Container Store Group, Inc. Announces Fourth Quarter and Full Fiscal 2021 Earnings Conference Call ( May-03-22 04:05PM )
# The Container Store Group, Inc.'s (NYSE:TCS) Stock Has Been Sliding But Fundamentals Look Strong: Is The Market Wrong? ( Apr-12-22 12:12PM )
# Tata Consultancy Earnings Trail Estimates After Labor Crunch Boosts Costs ( Apr-11-22 08:18AM )
# Payments Canada Partners with TCS to Evolve Payments with RTR ( Apr-05-22 02:45AM )
# The Container Store Introduces New Loyalty Program ( Mar-31-22 08:30AM )
# FAX Capital Corp. Reports Fourth Quarter and 2021 Results ( Mar-29-22 05:37PM )
# Tecsys Takes Store Fulfillment to the Next Level with Omnichannel Store-as-Warehouse Functionality ( Mar-28-22 08:00AM )
# Automation Takes Center Stage in Tecsys' New Omni WMS for Digital Commerce ( 08:00AM )
# Automation Takes Center Stage in Tecsys' New Omni WMS for Digital Commerce ( 08:00AM )
# 3 Growing Retailers Trading for Less Than 10 Times Earnings ( Mar-15-22 10:00AM )
# Is It Too Late To Consider Buying The Container Store Group, Inc. (NYSE:TCS)? ( Mar-10-22 05:11AM )
# The Container Store Group, Inc. Announces Participation in the UBS Global Consumer and Retail Conference ( Feb-23-22 08:00AM )
# Welcome to The Organization: The Container Store Launches New Logo, Brand Campaign, Welcome Offer ( Feb-22-22 08:00AM )
# Container Store, Inc. (The) -- Moody's announces completion of a periodic review of ratings of Container Store, Inc. (The) ( Feb-18-22 04:23PM )
# Satish Malhotra Is The CEO, President & Director of The Container Store Group, Inc. (NYSE:TCS) And They Just Picked Up 15% More Shares ( Feb-12-22 08:01AM )
# Container Store CEO talks earnings, e-commerce investment, and employee equity ( Feb-10-22 02:40PM )
# The Container Store Stock Tanked Today -- Is It Worth Buying? ( Feb-09-22 01:00PM )
# Why The Container Store Stock Plunged 24% at the Open Today ( 10:44AM )
# The Container Store stock plunges 20% after earnings ( Feb-08-22 06:54PM )
# The Container Store Group, Inc. Announces Third Quarter Fiscal 2021 Financial Results ( 04:05PM )
# The Container Store Announces Key New Hires ( Jun-02-21 09:00AM )
# Weekly CEO Buys Highlight ( May-24-21 11:05AM )
# Is Now The Time To Put Container Store Group (NYSE:TCS) On Your Watchlist? ( 09:14AM )
# Why Shares of The Container Store Group Jumped Today ( May-21-21 03:37PM )
# Why The Container Store Is Tumbling 10.5% Today ( May-19-21 12:11PM )
# The Container Store Group, Inc. Announces Fourth Quarter and Full Fiscal 2020 Financial Results ( May-18-21 04:05PM )
# The Container Store Group, Inc. to Host Earnings Call ( 02:45PM )
# The Container Store and Afterpay Partner to Deliver Flexible Payments ( May-17-21 08:00AM )
# The Container Store and Narvar Partner to Transform the Post-purchase Ecommerce Experience for Customers ( May-11-21 09:00AM )
# Instacart and The Container Store Partner to Launch Same-day Delivery Nationwide ( May-06-21 09:00AM )
# The Container Store Group, Inc. Announces Fourth Quarter and Full Year Fiscal 2020 Earnings Conference Call ( May-04-21 07:00AM )
# Imagine Holding Container Store Group (NYSE:TCS) Shares While The Price Zoomed 583% Higher ( Apr-27-21 06:51AM )
# Container Store, Inc. (The) -- Moody's announces completion of a periodic review of ratings of Container Store, Inc. (The) ( Apr-09-21 01:12PM )
# Are Strong Financial Prospects The Force That Is Driving The Momentum In The Container Store Group, Inc.'s NYSE:TCS) Stock? ( Mar-25-21 06:48AM )
# Bausch Health, Qualtrics See Activist Action ( Feb-19-21 08:08PM )
# More Retail Earnings, More Blaming Shipping Costs For Miss ( Feb-18-21 02:49PM )
# Should You Think About Buying The Container Store Group, Inc. (NYSE:TCS) Now? ( Feb-17-21 08:51AM )
# Container Store's stock pulls back from more than 5-year high after largest shareholder trims stake ( Feb-08-21 06:55AM )
# The Container Store Group, Inc. Announces Secondary Offering of Common Stock by Selling Stockholders ( 06:37AM )
# Why The Container Store Stock Rallied 16% at the Open Today ( Feb-03-21 11:02AM )
# Price Over Earnings Overview: Container Store Group ( 10:24AM )

# %%
parsed_news = []
for file_name, news_table in news_tables.items():
    for x in news_table.findAll('tr'):
        text = x.a.get_text() 
        date_scrape = x.td.text.split()

        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        else:
            date = date_scrape[0]
            time = date_scrape[1]

        ticker = file_name.split('_')[0]
        
        parsed_news.append([ticker, date, time, text])

# %%
analyzer = SentimentIntensityAnalyzer()

columns = ['Ticker', 'Date', 'Time', 'Headline']
news = pd.DataFrame(parsed_news, columns=columns)
#scores = news['Headline'].apply(analyzer.polarity_scores).tolist()

#df_scores = pd.DataFrame(scores)
#news = news.join(df_scores, rsuffix='_right')

# %%
news.head()
# Out:
#   Ticker       Date     Time  \
# 0    TCS  May-03-22  04:05PM
# 1    TCS  Apr-12-22  12:12PM
# 2    TCS  Apr-11-22  08:18AM
# 3    TCS  Apr-05-22  02:45AM
# 4    TCS  Mar-31-22  08:30AM
#
#                                             Headline
# 0  The Container Store Group, Inc. Announces Four...
# 1  The Container Store Group, Inc.'s (NYSE:TCS) S...
# 2  Tata Consultancy Earnings Trail Estimates Afte...
# 3  Payments Canada Partners with TCS to Evolve Pa...
# 4  The Container Store Introduces New Loyalty Pro...

# %%
news.to_csv('data.csv')

# %%
df = pd.read_csv('data.csv')

# %%
def review_clean(review): 
    # changing to lower case
    lower = review.str.lower()
    
    # Replacing the repeating pattern of &#039;
    pattern_remove = lower.str.replace("&#039;", "")
    
    # Removing all the special Characters
    special_remove = pattern_remove.str.replace(r'[^\w\d\s]',' ')
    
    # Removing all the non ASCII characters
    ascii_remove = special_remove.str.replace(r'[^\x00-\x7F]+',' ')
    
    # Removing the leading and trailing Whitespaces
    whitespace_remove = ascii_remove.str.replace(r'^\s+|\s+?$','')
    
    # Replacing multiple Spaces with Single Space
    multiw_remove = whitespace_remove.str.replace(r'\s+',' ')
    
    # Replacing Two or more dots with one
    dataframe = multiw_remove.str.replace(r'\.{2,}', ' ')
    
    return dataframe

# %%
df['Text'] = review_clean(df['Headline'])

# %%
stop_words = set(stopwords.words('english'))
df['Text'] = df['Text'].apply(lambda x: ' '.join(word for word in x.split() if word not in stop_words))

# %%
Snow_ball = SnowballStemmer("english")
df['Text'] = df['Text'].apply(lambda x: " ".join(Snow_ball.stem(word) for word in x.split()))

# %%
df.head()
# Out:
#    Unnamed: 0 Ticker       Date     Time  \
# 0           0    TCS  May-03-22  04:05PM
# 1           1    TCS  Apr-12-22  12:12PM
# 2           2    TCS  Apr-11-22  08:18AM
# 3           3    TCS  Apr-05-22  02:45AM
# 4           4    TCS  Mar-31-22  08:30AM
#
#                                             Headline  \
# 0  The Container Store Group, Inc. Announces Four...
# 1  The Container Store Group, Inc.'s (NYSE:TCS) S...
# 2  Tata Consultancy Earnings Trail Estimates Afte...
# 3  Payments Canada Partners with TCS to Evolve Pa...
# 4  The Container Store Introduces New Loyalty Pro...
#
#                                                 Text
# 0  contain store group inc announc fourth quarter...
# 1  contain store group inc nyse tcs stock slide f...
# 2  tata consult earn trail estim labor crunch boo...
# 3       payment canada partner tcs evolv payment rtr
# 4         contain store introduc new loyalti program

# %%
def sentiment(review):
    # Sentiment polarity of the reviews
    pol = []
    for i in review:
        analysis = TextBlob(i)
        pol.append(analysis.sentiment.polarity)
    return pol

# %%
df['sentiment'] = sentiment(df['Headline'])

# %%
df['sentiment_clean'] = sentiment(df['Text'])

# %%
df.head()
# Out:
#    Unnamed: 0 Ticker       Date     Time  \
# 0           0    TCS  May-03-22  04:05PM
# 1           1    TCS  Apr-12-22  12:12PM
# 2           2    TCS  Apr-11-22  08:18AM
# 3           3    TCS  Apr-05-22  02:45AM
# 4           4    TCS  Mar-31-22  08:30AM
#
#                                             Headline  \
# 0  The Container Store Group, Inc. Announces Four...
# 1  The Container Store Group, Inc.'s (NYSE:TCS) S...
# 2  Tata Consultancy Earnings Trail Estimates Afte...
# 3  Payments Canada Partners with TCS to Evolve Pa...
# 4  The Container Store Introduces New Loyalty Pro...
#
#                                                 Text  sentiment  \
# 0  contain store group inc announc fourth quarter...   0.175000
# 1  contain store group inc nyse tcs stock slide f...  -0.033333
# 2  tata consult earn trail estim labor crunch boo...   0.000000
# 3       payment canada partner tcs evolv payment rtr   0.000000
# 4         contain store introduc new loyalti program   0.136364
#
#    sentiment_clean
# 0         0.175000
# 1        -0.033333
# 2         0.000000
# 3         0.000000
# 4         0.136364

# %%
df.loc[(df['sentiment_clean'] >= 0.05), 'real_sentiment'] = 1
df.loc[(df['sentiment_clean'] < 0.05), 'real_sentiment'] = 0

# %%
df.head()
# Out:
#    Unnamed: 0 Ticker       Date     Time  \
# 0           0    TCS  May-03-22  04:05PM
# 1           1    TCS  Apr-12-22  12:12PM
# 2           2    TCS  Apr-11-22  08:18AM
# 3           3    TCS  Apr-05-22  02:45AM
# 4           4    TCS  Mar-31-22  08:30AM
#
#                                             Headline  \
# 0  The Container Store Group, Inc. Announces Four...
# 1  The Container Store Group, Inc.'s (NYSE:TCS) S...
# 2  Tata Consultancy Earnings Trail Estimates Afte...
# 3  Payments Canada Partners with TCS to Evolve Pa...
# 4  The Container Store Introduces New Loyalty Pro...
#
#                                                 Text  sentiment  \
# 0  contain store group inc announc fourth quarter...   0.175000
# 1  contain store group inc nyse tcs stock slide f...  -0.033333
# 2  tata consult earn trail estim labor crunch boo...   0.000000
# 3       payment canada partner tcs evolv payment rtr   0.000000
# 4         contain store introduc new loyalti program   0.136364
#
#    sentiment_clean  real_sentiment
# 0         0.175000             1.0
# 1        -0.033333             0.0
# 2         0.000000             0.0
# 3         0.000000             0.0
# 4         0.136364             1.0

# %%
df.to_csv('data1.csv')

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df, test_size = 0.25, random_state = 0)

# checking the shape 
print("Shape of train:", df_train.shape)
print("Shape of test: ", df_test.shape)
# Out:
# Shape of train: (75, 9)
# Shape of test:  (25, 9)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline

cv = CountVectorizer(max_features = 20000, ngram_range = (4, 4))
pipeline = Pipeline([('vect',cv)])

df_train_features = pipeline.fit_transform(df_train['Text'])
df_test_features = pipeline.fit_transform(df_test['Text'])

print("df_train_features :", df_train_features.shape)
print("df_test_features :", df_test_features.shape)
# Out:
# df_train_features : (75, 389)
# df_test_features : (25, 138)

# %%
y_train = df_train['real_sentiment']
y_test = df_test['real_sentiment']
solution = y_test.copy()

# %% [markdown]
# ## Normal CNN

# %%
import keras 
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Bidirectional
from keras.layers import BatchNormalization
from keras.layers import LSTM
from keras.preprocessing.sequence import pad_sequences

# %%
model = keras.models.Sequential()

model.add(keras.layers.Dense(200, input_shape=(389,)))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Activation('relu'))
model.add(keras.layers.Dropout(0.5))

model.add(keras.layers.Dense(300))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Activation('relu'))
model.add(keras.layers.Dropout(0.5))

model.add(keras.layers.Dense(100, activation = 'relu'))
model.add(keras.layers.Dense(1, activation = 'sigmoid'))

#  Model compile
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
df_train_features = df_train_features.toarray()

# %%
hist = model.fit(df_train_features, y_train, epochs=15, batch_size=64)
# Out:
# Epoch 1/15
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3801 - accuracy: 0.8533
# Epoch 2/15
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3902 - accuracy: 0.8000
# Epoch 3/15
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3686 - accuracy: 0.8800
# Epoch 4/15
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3389 - accuracy: 0.8400
# Epoch 5/15
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2722 - accuracy: 0.9200
# Epoch 6/15
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3168 - accuracy: 0.8933
# Epoch 7/15
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2343 - accuracy: 0.9067
# Epoch 8/15
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2548 - accuracy: 0.9067
# Epoch 9/15
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1909 - accuracy: 0.9467
# Epoch 10/15
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1773 - accuracy: 0.9733
# Epoch 11/15
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1988 - accuracy: 0.9333
# Epoch 12/15
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1755 - accuracy: 0.9067
# Epoch 13/15
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1663 - accuracy: 0.9733
# Epoch 14/15
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1204 - accuracy: 0.9733
# Epoch 15/15
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.9867
